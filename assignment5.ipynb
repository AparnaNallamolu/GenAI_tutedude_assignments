# %% [markdown]
# # Assignment 5

# %% [markdown]
# ## Task 1: Create a simple Module (math_utils.py)

# %%
'''
Create a module math_utils.py with the following functions:
    1. add(a,b) --> return a+b
    2. substract(a,b) --> return a - b
    3. square(n) --> return n2

in main.py import this module in two different ways:

    import math_utils
    from math_utils import square

test all functions
'''

# %%
import math_utils

# %%
math_utils.add(3,4)
# Out:
# 7

# %%
math_utils.substract(65,55)
# Out:
# 10

# %%
math_utils.square(5)
# Out:
# 25

# %%
from math_utils import square

# %%
square(5)
# Out:
# 25

# %%
from math_utils import add

# %%
add(65,99)
# Out:
# 164

# %%
from math_utils import substract

# %%
substract(89,20)
# Out:
# 69

# %% [markdown]
# ## Task 2: Create another Module (string_utils.py)

# %%
'''
Create a module string_utils.py with:

    1. Capitalize_words(text) --> return text with each word capitalized
    2. reverse_string(text) --> returns reversed string
    3. word_count(text) --> returns number of words in the text

Import this module in main.py and test all functions
'''

# %%
import string_utils

# %%
text_data = 'my name is aparna'

string_utils.capitalize_words(text_data)
# Out:
# 'My name is aparna'

# %%
string_utils.reverse_string(text_data)
# Out:
# 'anrapa si eman ym'

# %%
string_utils.word_count(text_data)
# Out:
# 17

# %% [markdown]
# ## Task 3: Create a simple Package (shop_package)

# %%
'''
Inside folder shop_package/, create:

Discount.py

functions: 
    1. Apply discount(price, percent) --> return discounted price
    2. flat_discount(price) -> always substract 50 from price


billing.py
Functions:

    1. calculate_total(prices) -> return total bill
    2. apply_tax(amount) --> adds 5% tax

__init__.py
leave it empty or add:
from discount import apply_discount, flat_discount
from billing import calculate_total, apply_tax
( This allows calling functions directly from the package)
'''

# %% [markdown]
# ## Task 4: Importing the packages in main.py

# %%
'''
In main.py do the following:

1 import shop_package.discount as disc
2. from shop_package.billing import calculate_total
3. call every function inside the package.

example Usage:
print(disc.apply_discount(1000, 10))
print(calculate_total([100,200,300]))
'''

# %%
import shop_package.discount as disc

# %%
print(disc.apply_discount(1000,10))
# Out:
# 900.0

# %%
from shop_package.billing import calculate_total

# %%
print(calculate_total([100,200,300]))
# Out:
# 600
