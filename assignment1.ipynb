# %% [markdown]
# # Assignment1: Python - Data Stuctures

# %% [markdown]
# ## Task1: Product Collection (Lists & Tuples)

# %%
# 1. Create a list named products contains at lease 6 product names (string)
products=['biscuits', 'chocolates', 'granola bars', 'mobile', 'printer', 'tablet']

# %%
print(type(products))
products
# Out:
# <class 'list'>
# ['biscuits', 'chocolates', 'books', 'mobile', 'printer', 'tablet']

# %%
# 2. Create a tuple named smaple product that stores (product_name, price, category)

sample_product = (('Biscuits', 20, 'grocery'), ('chocolates', 50, 'grocery'), ('granola bars', 40, 'grocery'),
('mobile', 6000, 'Electronics'), ('printer', 600000, 'Electronics'), ('tablet', 16000, 'Electronics'))

# %%
print(type(sample_product))
sample_product
# Out:
# <class 'tuple'>
# (('Biscuits', 20, 'grocery'),
#  ('chocolates', 50, 'grocery'),
#  ('granola bars', 40, 'grocery'),
#  ('mobile', 6000, 'Electronics'),
#  ('printer', 600000, 'Electronics'),
#  ('tablet', 16000, 'Electronics'))

# %%
# 3. Print the 2nd and last product from the products list.
print(products)
print(products[4:])
# Out:
# ['biscuits', 'chocolates', 'books', 'mobile', 'printer', 'tablet']
# ['printer', 'tablet']

# %%
# 4. Append two new product names to products and then print the updated list
products.append('cereal')

# %%
products.append('airpods')

# %%
print(products)
# Out:
# ['biscuits', 'chocolates', 'books', 'mobile', 'printer', 'tablet', 'cereal', 'airpods']

# %%
# Extra (optional): Covert sample_product into a list, change the price and convert it back to a tuple

print(sample_product)
# Out:
# (('Biscuits', 20, 'grocery'), ('chocolates', 50, 'grocery'), ('granola bars', 40, 'grocery'), ('mobile', 6000, 'Electronics'), ('printer', 600000, 'Electronics'), ('tablet', 16000, 'Electronics'))

# %%
sample_list = [list(item) for item in sample_product]

# %%
print(sample_list)
type(sample_list)
# Out:
# [['Biscuits', 20, 'grocery'], ['chocolates', 50, 'grocery'], ['granola bars', 40, 'grocery'], ['mobile', 6000, 'Electronics'], ['printer', 600000, 'Electronics'], ['tablet', 16000, 'Electronics']]
# list

# %%
sample_list[0][1] = 50
sample_list[1][1] = 100
sample_list[2][1] = 75
sample_list[3][1] = 16000
sample_list[4][1] = 750000
sample_list[5][1] = 20000

# %%
sample_list
# Out:
# [['Biscuits', 50, 'grocery'],
#  ['chocolates', 100, 'grocery'],
#  ['granola bars', 75, 'grocery'],
#  ['mobile', 16000, 'Electronics'],
#  ['printer', 750000, 'Electronics'],
#  ['tablet', 20000, 'Electronics']]

# %%
sample_tuple = tuple(tuple(item) for item in sample_list)

# %%
sample_tuple
# Out:
# (('Biscuits', 50, 'grocery'),
#  ('chocolates', 100, 'grocery'),
#  ('granola bars', 75, 'grocery'),
#  ('mobile', 16000, 'Electronics'),
#  ('printer', 750000, 'Electronics'),
#  ('tablet', 20000, 'Electronics'))

# %% [markdown]
# ## Task 2: Categories (sets)

# %%
# From your products list, create a set of categories called categories_set 
# (if product names do not contain categories, create a short parallel list categories=[....] 
# with matching length and use that)

# %%
products
# Out:
# ['biscuits',
#  'chocolates',
#  'books',
#  'mobile',
#  'printer',
#  'tablet',
#  'cereal',
#  'airpods']

# %%
categories_set = ['grocery','Mobile','tab','hardware','Electronics']

# %%
category=set(categories_set)

# %%
category
# Out:
# {'Electronics', 'Mobile', 'grocery', 'hardware', 'tab'}

# %% [markdown]
# #### 2. Demonstrate adding a new category to the set and show that duplicates are ignored

# %%
categories_set.append('Mobile')

# %%
categories_set
# Out:
# ['grocery', 'Mobile', 'tab', 'hardware', 'Electronics', 'Mobile']

# %%
category
# Out:
# {'Electronics', 'Mobile', 'grocery', 'hardware', 'tab'}

# %%
# 3. Show how to check whether a category exists in the set (print a boolean result). 
cat = input('Enter the category name:')

for items in categories_set:
    #print(items)
    if cat==items:
       print(True)
    if cat!=items:
        print(False)
# Out:
# False
# True
# False
# False
# False
# True

# %%
# 3. Show how to check whether a category exists in the set (print a boolean result). 
print('Mobile' in categories_set)
print('telephone' in categories_set)
# Out:
# True
# False

# %%
# Extra (optional) show how to get the total number of unique categories using a set
categories_set
# Out:
# ['grocery', 'Mobile', 'tab', 'hardware', 'Electronics', 'Mobile']

# %%
len(categories_set)
# Out:
# 6

# %%
categories = set(categories_set)
len(categories)
# Out:
# 5

# %% [markdown]
# ## Task 3 Product Pricing (Dictionaries)

# %%
# 1. create a dictionary pirce_dict where keys are product name and values are prices (integer or float).
# Include atleast 6 entries

price_dict = {'Mobile':6000,
'Printer':60000.75,
'Tablet':18000,
'airpods':1000,
'chocolates':100.77,
'cooler':7000}

print(price_dict)
# Out:
# {'Mobile': 6000, 'Printer': 60000.75, 'Tablet': 18000, 'airpods': 1000, 'chocolates': 100.77, 'cooler': 7000}

# %%
# write a small code block to
#add a new product with price to price_dict
        #- update the price of an existing product
        #- Remove a product by name (handle the case when the product doesnt exist)

price_dict
# Out:
# {'Mobile': 6000,
#  'Printer': 60000.75,
#  'Tablet': 18000,
#  'airpods': 1000,
#  'chocolates': 100.77,
#  'cooler': 7000}

# %%
price_dict
# Out:
# {'Mobile': 6000,
#  'Printer': 60000.75,
#  'Tablet': 18000,
#  'airpods': 1000,
#  'chocolates': 100.77,
#  'cooler': 7000,
#  'AC': 15000.1,
#  'Airpods': 15000.1}

# %%
ke='Airpods'
va=15000.1
price_dict[ke]=vafor key1 in price_dict.items():
    if ke!=key1:
        price_dict[ke]=va
    if ke==key1:
        price_dict[key1]=va
print(price_dict)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[257], line 4
#       1 ke='Airpods'
#       2 va=15000.1
# ----> 4 for key1 in price_dict.items():
#       5     if ke!=key1:
#       6         price_dict[ke]=va
#
# RuntimeError: dictionary changed size during iteration

# %%
del price_dict['Airpods']

# %%
price_dict
# Out:
# {'Mobile': 6000,
#  'Printer': 60000.75,
#  'Tablet': 18000,
#  'airpods': 1000,
#  'chocolates': 100.77,
#  'cooler': 7000,
#  'AC': 15000.1}

# %%
# 3. Print the average price of all prodcuts (using only dictionary operations and basic arithmetic)

price_dict.values()
total_sum=sum(price_dict.values())
total_count=len(price_dict)
print(f'Total sum: {total_sum}')
print(f'Total length: {total_count}')

average = total_sum / total_count
print(f'Average: {average}')
# Out:
# Total sum: 107101.62
# Total length: 7
# Average: 15300.231428571427

# %%
# Extra: Print the product with both the maximum price and minimum price
print(price_dict.items())
maximum = max(price_dict, key = price_dict.get)
print(maximum)
minimum = min(price_dict, key = price_dict.get)
print(minimum)
# Out:
# dict_items([('Mobile', 6000), ('Printer', 60000.75), ('Tablet', 18000), ('airpods', 1000), ('chocolates', 100.77), ('cooler', 7000), ('AC', 15000.1)])
# Printer
# chocolates

# %% [markdown]
# ## Task 4 Combined Operations

# %%
# Using the products list and price_dict, create a list of tuples named catalog using each tuple is (product_name,price, category).


price_dict


categories = ["Mobile", "Printer", "Tablet", "Audio", "Grocery","Electronics", "Electronics"]


product_names = list(price_dict.keys())


catalog = []

for i in range(len(product_names)):
    name = product_names[i]
    price = price_dict[name]
    category = categories[i]
    
    
    catalog.append((name, price, category))


for item in catalog:
    print(item)
# Out:
# ('Mobile', 6000, 'Mobile')
# ('Printer', 60000.75, 'Printer')
# ('Tablet', 18000, 'Tablet')
# ('airpods', 1000, 'Audio')
# ('chocolates', 100.77, 'Grocery')
# ('cooler', 7000, 'Electronics')
# ('AC', 15000.1, 'Electronics')

# %%
# 2. From catalog, create a new dictionary category to products that aps each category to a list of product names in that category

catalog 


category_to_products = {}

for product_name, price, category in catalog:
   
    if category not in category_to_products:
        category_to_products[category] = []
    
   
    category_to_products[category].append(product_name)

# %%
category_to_products
# Out:
# {'Mobile': ['Mobile'],
#  'Printer': ['Printer'],
#  'Tablet': ['Tablet'],
#  'Audio': ['airpods'],
#  'Grocery': ['chocolates'],
#  'Electronics': ['cooler', 'AC']}

# %%
# 3. Print all products that belong to the category that has maximum number of products

maxim = max(category_to_products.values())
print(maxim)
# Out:
# ['cooler', 'AC']
